# %% [markdown]
# # **0.0) CLONING GITHUB REPO INTO GOOGLE COLAB**

# %%
# !git clone https://github.com/AshishJangra27/datasets
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 328, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 328 (delta 19), reused 54 (delta 9), pack-reused 235 (from 1)
# Receiving objects: 100% (328/328), 278.62 MiB | 17.02 MiB/s, done.
# Resolving deltas: 100% (145/145), done.
# Updating files: 100% (225/225), done.

# %% [markdown]
# # **A)DATA EXPLORATION**
#
# 1. Loading Dataset
# 2. Importing Libraries
# 3. Loading datset into variable
# 4. Exploring- .info(),.decribe(), .head(), .tail()
# 5. Checking For Null Values- .isnull.sum()
# 6. Droping rows with null values: .dropna()
# 7. Check for Duplicate Rows: df['cloumn'].duplicated().sum()
# 8. Applying Filters: df[df['column']=='value]]
# 9. Finding len: len(df[df['column']=='value]])
# 10. Finding Unique : df['columnnname'].unique()
# 11. Number of Uniques: df['cloumnname'].nunique()
# 12. Taking an assumption and exploring and removing duplicates
# 13. Dropping the Duplicates : df.drop_duplicates(subset='link', inplace=True)
# 14. Check teh count/frequency of each value in a column using : df['duration'].value_counts()
# 15. Sort the values inside the column: **df['link'].value_counts().sort_values(ascending=False)**
# Ascending= True> For ascending order
# Ascending= Falase> For Descending order
# 16. df['language'].value_counts().sort_values(ascending=True).plot(kind='bar')

# %%
'/content/datasets/Gaana/songs.csv'
# Out:
# '/content/datasets/Gaana/songs.csv'

# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('/content/datasets/Gaana/songs.csv')
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41355 entries, 0 to 41354
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       41355 non-null  object
#  1   singer     41355 non-null  object
#  2   singer_id  41355 non-null  object
#  3   duration   41355 non-null  object
#  4   link       41355 non-null  object
#  5   language   41355 non-null  object
# dtypes: object(6)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#                        name           singer                singer_id  \
# count                 41355            41355                    41355
# unique                31534             6196                     6580
# top     O Mere Dil Ke Chain  Lata Mangeshkar  /artist/lata-mangeshkar
# freq                     26             1410                     1410
#
#        duration                 link language
# count     41355                41355    41355
# unique     1309                36361       16
# top       03:02  /kya-khoob-lagti-ho   Telugu
# freq        447                    2     4996

# %%
df.head() #by default top 5 rows, but param of number of rows can be passed
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                       /artist/jagjeet-singh-1    03:41
# 3                          /artist/chitra-singh    04:26
# 4                       /artist/jagjeet-singh-1    05:39
#
#                                   link language
# 0                 /dil-e-nadan-tujhe-3     Urdu
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu
# 2                       /unke-dekhe-se     Urdu
# ...

# %%
df.head(10)
# Out:
#                                                 name  \
# 0                              Dil - E - Nadan Tujhe
# 1                  Agar Hum Kahen Aur Woh Muskara De
# 2                                      Unke Dekhe Se
# 3            Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                            Hazaron Khwahishen Aisi
# 5               Suna Tha Ki Woh Aayenge Anjuman Mein
# 6  Bahut Pahele Se Un Qadmon Ki Aahat Jaan Lete Hain
# 7                        Tum Itna Jo Muskura Rahe Ho
# 8                           Tum Apna Ranjhogham Apni
# 9                    Dialogues And Ishq Mujhko Nahin
#
#                           singer  \
# 0      Chitra Singh|Jagjit Singh
# 1      Chitra Singh|Jagjit Singh
# 2                   Jagjit Singh
# 3                   Chitra Singh
# 4                   Jagjit Singh
# 5      Chitra Singh|Jagjit Singh
# 6      Chitra Singh|Jagjit Singh
# 7                   Jagjit Singh
# 8                    Jagjit Kaur
# 9  Chitra Singh|Naseeruddin Shah
#
# ...

# %%
df.tail() #Last 5 rows
# Out:
#                                                     name  \
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 41350                   Kishore Kumar
# 41351                    Feroza Begum
# 41352  Sandhya Mukherjee|Hemant Kumar
# 41353                Ajoy Chakrabarty
# 41354                     Asha Bhosle
#
#                                                singer_id duration  \
# 41350                              /artist/kishore-kumar    03:23
# 41351                               /artist/feroza-begum    03:56
# 41352  /artist/sandhya-mukherjee|/artist/hemanta-mukh...    07:36
# 41353                           /artist/ajoy-chakrabarty    04:29
# ...

# %%
df.isnull() #This will return the entire datset with True and False Values
# Out:
#         name  singer  singer_id  duration   link  language
# 0      False   False      False     False  False     False
# 1      False   False      False     False  False     False
# 2      False   False      False     False  False     False
# 3      False   False      False     False  False     False
# 4      False   False      False     False  False     False
# ...      ...     ...        ...       ...    ...       ...
# 41350  False   False      False     False  False     False
# 41351  False   False      False     False  False     False
# 41352  False   False      False     False  False     False
# 41353  False   False      False     False  False     False
# 41354  False   False      False     False  False     False
#
# [41355 rows x 6 columns]

# %%
df.isnull().sum() #sum the entire isnull=true values of every column
# Out:
# name         0
# singer       0
# singer_id    0
# duration     0
# link         0
# language     0
# dtype: int64

# %%
df.dropna() #It drops the rows that has missing or null values
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
#Checking Duplicates
df['link'].duplicated().sum()
# Out:
# 4994

# %%
df['singer'] == 'Jagjit Singh' #It returns True/False
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 41350    False
# 41351    False
# 41352    False
# 41353    False
# 41354    False
# Name: singer, Length: 41355, dtype: bool

# %%
df[df['singer']=='Jagjit Singh'] #The inside code is giving True/False and we are passing it into DF, so it returns only the record where singer value=Jagjit singh was true
# Out:
#                                     name        singer  \
# 2                          Unke Dekhe Se  Jagjit Singh
# 4                Hazaron Khwahishen Aisi  Jagjit Singh
# 7            Tum Itna Jo Muskura Rahe Ho  Jagjit Singh
# 10          Zindagi Se Badi Saza Hi Nahi  Jagjit Singh
# 11                 Kabse Hoon Kya Bataon  Jagjit Singh
# ...                                  ...           ...
# 27093  Woh Kagaz Ki Kasti (Part 1 And 2)  Jagjit Singh
# 27157       Woh Kagaz Ki Kashti (Part 2)  Jagjit Singh
# 27369         Tujhse Milne Ki Saza Denge  Jagjit Singh
# 27393               Pyar Mujh Se Jo Kiya  Jagjit Singh
# 27852       Shayad Main Zindagi Ki Sahar  Jagjit Singh
#
#                      singer_id duration                             link  \
# 2      /artist/jagjeet-singh-1    03:41                   /unke-dekhe-se
# 4      /artist/jagjeet-singh-1    05:39       /hazaron-khwahishen-aisi-1
# 7      /artist/jagjeet-singh-1    05:21  /tum-itna-jo-muskura-rahe-ho-12
# ...

# %%
#To check length or number of rows:
len(df[df['singer']=='Jagjit Singh'])
# Out:
# 172

# %%
df['language'].unique()
# Out:
# array(['Urdu', 'Gujarati', 'Tamil', 'Kannada', 'Rajasthani', 'Haryanvi',
#        'Punjabi', 'Hindi', 'Old', 'Malayalam', 'Marathi', 'Telugu',
#        'Odia', 'Bhojpuri', 'Assamese', 'Bengali'], dtype=object)

# %%
df['language'].nunique()
# Out:
# 16

# %%
#Find the records of Urdu Ghazal by Jagjit Singh
df[(df['language']=='Urdu') & (df['singer']=='Jagjit Singh')]
# Out:
#                                                   name        singer  \
# 2                                        Unke Dekhe Se  Jagjit Singh
# 4                              Hazaron Khwahishen Aisi  Jagjit Singh
# 7                          Tum Itna Jo Muskura Rahe Ho  Jagjit Singh
# 10                        Zindagi Se Badi Saza Hi Nahi  Jagjit Singh
# 11                               Kabse Hoon Kya Bataon  Jagjit Singh
# 13                             Hazaron Khwahishen Aisi  Jagjit Singh
# 15                               Zulmat Kade Mein Mere  Jagjit Singh
# 16                           Na Tha Kuchh To Khuda Tha  Jagjit Singh
# 22                      Woh Firaaq Aur Woh Visal Kahan  Jagjit Singh
# 23                    Phir Kuch Ek Dil Ko Beqarari Hai  Jagjit Singh
# 24                           Kabhi Ghuncha Kabhi Shola  Jagjit Singh
# 25                          Naksh Rariyaaadi Hai Kiski  Jagjit Singh
# 30         Bas Ke Dusavar Hain Har Kaam Ka Aasaan Hona  Jagjit Singh
# ...

# %%
#Handling Missing Values
df['link'].duplicated().sum()
# Out:
# 4994

# %%
df_ = df[df['link'].duplicated()]  # Storing the duplicated values in df_ variable
df_
# Out:
#                               name                         singer  \
# 23047    Bheegi Bheegi Raaton Mein  Kishore Kumar|Lata Mangeshkar
# 23048      Aap Ki Ankhon Mein Kuch  Kishore Kumar|Lata Mangeshkar
# 23049  Tum Aa Gaye Ho Noor Aa Gaya  Kishore Kumar|Lata Mangeshkar
# 23050       Hamen Tumse Pyar Kitna                  Kishore Kumar
# 23051         Tere Bina Zindagi Se  Kishore Kumar|Lata Mangeshkar
# ...                            ...                            ...
# 28036  Apne Hathon Ki Lakiron Mein                   Manhar Udhas
# 28037  Gori Chalo Na Hans Ki Chaal      Asha Bhosle|Mohammed Rafi
# 28038     Zindagi Ki Na Toote Ladi   Lata Mangeshkar|Nitin Mukesh
# 28039         Diwana Leke Aaya Hai                  Kishore Kumar
# 37215        Intheraa Ee Jeevitham                    Ghanatasala
#
#                                            singer_id duration  \
# 23047  /artist/kishore-kumar|/artist/lata-mangeshkar    03:54
# ...

# %%
df_.describe() #Observing the duplicated data
# Out:
#                        name           singer                singer_id  \
# count                  4994             4994                     4994
# unique                 3821              923                      927
# top     O Mere Dil Ke Chain  Lata Mangeshkar  /artist/lata-mangeshkar
# freq                     13              554                      554
#
#        duration                        link language
# count      4994                        4994     4994
# unique      527                        4994        2
# top       04:01  /bheegi-bheegi-raaton-mein      Old
# freq         55                           1     4993

# %%
# It is inferered that all the somgs in the duplicated data are of 2 language.
# One of the languge is Old which has 4993 values and the other language has 1 value as dupliacte
# Lets check if old is a language in the df
df['language'].unique()
# Out:
# array(['Urdu', 'Gujarati', 'Tamil', 'Kannada', 'Rajasthani', 'Haryanvi',
#        'Punjabi', 'Hindi', 'Old', 'Malayalam', 'Marathi', 'Telugu',
#        'Odia', 'Bhojpuri', 'Assamese', 'Bengali'], dtype=object)

# %%
# Assumption: The songs of old type are duplicates and of Hindi type
# Checking Assumption 1 by observing Top 10 rows of df_
df_.head(10)
# Out:
#                                name                         singer  \
# 23047     Bheegi Bheegi Raaton Mein  Kishore Kumar|Lata Mangeshkar
# 23048       Aap Ki Ankhon Mein Kuch  Kishore Kumar|Lata Mangeshkar
# 23049   Tum Aa Gaye Ho Noor Aa Gaya  Kishore Kumar|Lata Mangeshkar
# 23050        Hamen Tumse Pyar Kitna                  Kishore Kumar
# 23051          Tere Bina Zindagi Se  Kishore Kumar|Lata Mangeshkar
# 23052   Kora Kagaz Tha Yeh Man Mera  Kishore Kumar|Lata Mangeshkar
# 23053           Lag Ja Gale Se Phir                Lata Mangeshkar
# 23054              Ae Mere Humsafar       Udit Narayan|Alka Yagnik
# 23055         Ek Ajnabee Haseena Se                  Kishore Kumar
# 23056  Tere Mere Milan Ki Yeh Raina  Kishore Kumar|Lata Mangeshkar
#
#                                            singer_id duration  \
# 23047  /artist/kishore-kumar|/artist/lata-mangeshkar    03:54
# 23048  /artist/kishore-kumar|/artist/lata-mangeshkar    04:09
# ...

# %%
# Checking assumption 2 if all the songs od old type are Hindi
df['language'].value_counts() #It returns the unique values of each value in Language column
# Out:
# language
# Telugu        4996
# Hindi         4993
# Old           4993
# Marathi       4699
# Tamil         4677
# Punjabi       3818
# Kannada       3559
# Urdu          3116
# Gujarati      2115
# Bengali        958
# Odia           940
# Assamese       724
# Rajasthani     541
# Bhojpuri       519
# Malayalam      479
# Haryanvi       228
# Name: count, dtype: int64

# %%
# From the above , it is clear that all the old type songs are dupliacte of Hindi songsas number of old and hindi are similar

# %%
df.drop_duplicates(subset='link', inplace=True)
# the above statement can also be written as
# df = df.drop_duplicates(subset='link')
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
df['link'].duplicated().sum()
# Out:
# 0

# %%
# THE DATA IS CLEANED FROM ROW-WISE PERSPECTIVE. It does not contain null values and dupliacte values

# %%
#Now, we need to clean the data column wise,eg: the datatype of duration is string. So we need to fix that

# %%
# Analysing Column Wise
# Exploring Singer

df['singer'].value_counts().head(20)
# Out:
# singer
# S. P. Balasubrahmanyam                1151
# Asha Bhosle                           1037
# P. Susheela                           1019
# Lata Mangeshkar                        856
# S. Janaki                              728
# Mohammed Rafi                          698
# S. P. Balasubrahmanyam|P. Susheela     682
# Kishore Kumar                          663
# Noor Jehan                             489
# S. P. Balasubrahmanyam|S. Janaki       455
# Ghanatasala                            454
# K J Yesudas                            410
# T.M. Soundararajan                     408
# P.B. Sreenivas                         391
# Ghanatasala|P. Susheela                373
# Usha Mangeshkar                        309
# L.R. Eswari                            276
# Anuradha Paudwal                       265
# S. Janaki|S. P. Balasubrahmanyam       252
# Mahendra Kapoor                        246
# Name: count, dtype: int64

# %%
# One thing can be inferred from analysing the column datatype. That one singer
# has sung many songs, so to extract number of songs per singer, it must go through
#every row data and search for singers name
# Another way can be to reconstruct column like Singer 1, singer2 per row

# %%
df['duration'].value_counts().head(10)
# Out:
# duration
# 03:02    417
# 04:00    385
# 03:21    365
# 05:00    358
# 03:03    353
# 03:18    348
# 03:23    346
# 03:17    345
# 03:13    323
# 03:19    321
# Name: count, dtype: int64

# %%
df['link'].value_counts().sort_values(ascending=True)
# Out:
# link
# /dil-e-nadan-tujhe-3                                 1
# /kab-se-hoon-kya-bataoon                             1
# /tujhe-milne-ki-saza-denge                           1
# /na-tha-kuchh-to-khuda-tha                           1
# /dialogues-82                                        1
#                                                     ..
# /amar-kantho-hote-gaan-ke-nilo                       1
# /chaaridike-paaper-andhar-manush-janam-diye-bidhi    1
# /ei-kigo-sesh-daan                                   1
# /the-hero                                            1
# /tomar-je-oi-haater-mala                             1
# Name: count, Length: 36361, dtype: int64

# %%
df['language'].value_counts().sort_values(ascending=True).plot(kind='bar')
# Out:
# <Axes: xlabel='language'>

# %%
for i in df['duration'][:12]: # retuning 12 rows
  print(i)
# Out:
# 05:00
# 06:26
# 03:41
# 04:26
# 05:39
# 07:59
# 04:48
# 05:21
# 03:09
# 04:24
# 05:03
# 04:00

# %%
#Need to Re-construct Duration column
for i in df['duration'][:10]:
  print(i.split(':'))
# This will split the duration on the delimiter : and return a list
# Out:
# ['05', '00']
# ['06', '26']
# ['03', '41']
# ['04', '26']
# ['05', '39']
# ['07', '59']
# ['04', '48']
# ['05', '21']
# ['03', '09']
# ['04', '24']

# %%
# Need to take the first item of the list and * with 60 to get seconds and add the second item to it
for i in df['duration'][:10]:
  print(i.split(':')[0]) #this will print the zero index of the list
# Out:
# 05
# 06
# 03
# 04
# 05
# 07
# 04
# 05
# 03
# 04

# %%
#Duration of string type to Duration in seconds of int type conversion
for i in df['duration'][:10]:
  print(i, int(i.split(':')[0])*60 + int(i.split(':')[1]))
# Out:
# 05:00 300
# 06:26 386
# 03:41 221
# 04:26 266
# 05:39 339
# 07:59 479
# 04:48 288
# 05:21 321
# 03:09 189
# 04:24 264

# %%
# But the conversion is not stored
# Final Code for conversion
duration_seconds = []
for i in df['duration']:
  duration_seconds.append(int(i.split(':')[0])*60 + int(i.split(':')[1]))

df['duration_in_seconds'] = duration_seconds
# A new column named duration_in_seconds will be created and will be assigned the duration_seconds values
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
df['duration_in_seconds'].sort_values(ascending=False)
# Out:
# 818      3595
# 14098    3588
# 13282    3587
# 39216    3581
# 30833    3566
#          ...
# 9480       19
# 36778      18
# 6500       18
# 35561      17
# 22952      17
# Name: duration_in_seconds, Length: 36361, dtype: int64

# %%
# The highest value is of 3588 whhich is close to 3600~ 1 hr. There might also be songs more than 1 hr
# We didn't consider this case while coding

# %%
duration_seconds = []
for i in df['duration']:
  if len(i.split(':')) == 2:
        duration_seconds.append(int(i.split(':')[0])*60 + int(i.split(':')[1]))
  if len(i.split(':')) == 3:
         hours= int(i.split(':')[0])
         minutes= int(i.split(':')[1])
         seconds= int(i.split(':')[2])
         duration_seconds.append(hours*60*60 + minutes*60 + seconds)

df['duration_in_seconds'] = duration_seconds
# A new column named duration_in_seconds will be created and will be assigned the duration_seconds values
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
df['duration_in_seconds'].sort_values(ascending=False)
# Out:
# 16093    25680
# 16352    24720
# 15000    24720
# 15025    21840
# 14624    21780
#          ...
# 9480        19
# 36778       18
# 6500        18
# 35561       17
# 22952       17
# Name: duration_in_seconds, Length: 36361, dtype: int64

# %%
# Sorting the whole dataset based on the Duartion _in_Seonds column in descending order
df.sort_values(by='duration_in_seconds', ascending=False).head()
# Out:
#                                name          singer               singer_id  \
# 16093                    Haye Tumba  Dilshad Akhtar  /artist/dilshad-akhtar
# 16352                Bum Bum Lahiri  Dilshad Akhtar  /artist/dilshad-akhtar
# 15000                Bum Bum Lahiri  Dilshad Akhtar  /artist/dilshad-akhtar
# 15025          Kanu Atharu Bahoundi  Dilshad Akhtar  /artist/dilshad-akhtar
# 14624  Desi Bandri Vilayati Cheekan  Dilshad Akhtar  /artist/dilshad-akhtar
#
#        duration                             link language  duration_in_seconds
# 16093  07:08:00                      /haye-tumba  Punjabi                25680
# 16352  06:52:00                  /bum-bum-lahiri  Punjabi                24720
# 15000  06:52:00                /bum-bum-lahiri-1  Punjabi                24720
# 15025  06:04:00            /kanu-atharu-bahoundi  Punjabi                21840
# 14624  06:03:00  /desi-bandri-vilayati-cheekan-1  Punjabi                21780

# %% [markdown]
# # **B) AGENDA OF ANAYSIS**
#
# ## B.1: OVERALL ANALYSIS
# 1. Total Songs
# 2. Total Singers
# 3. Languages
# 4. Total Song Plays - Data Insufficient
# 5. Play in Hours || 100 million hours
# 6. Genre of Songs - Data Insufficient
#
# ## B.2: YEARLY ANALYSIS
# 7. Top Songs of the Year
# 8. Top Singers of the Year
#
# ## B.3: MONTHLY ANALYSIS
# 7. Top Songs of the Month
# 8. Top Singers of the Month
#
# ## B.4: WEELY ANALYSIS
# 9. Top Songs of the Week
# 10. Top Singers of the Week

# %%
# Total Songs
print(df['link'].nunique(), len(df))
# Out:
# 36361 36361

# %%
# Total Singers

#Splittinh the singer id column
df['singer_id'].str.split('|')
# Out:
# 0          [/artist/chitra-singh, /artist/jagjeet-singh-1]
# 1          [/artist/chitra-singh, /artist/jagjeet-singh-1]
# 2                                [/artist/jagjeet-singh-1]
# 3                                   [/artist/chitra-singh]
# 4                                [/artist/jagjeet-singh-1]
#                                ...
# 41350                              [/artist/kishore-kumar]
# 41351                               [/artist/feroza-begum]
# 41352    [/artist/sandhya-mukherjee, /artist/hemanta-mu...
# 41353                           [/artist/ajoy-chakrabarty]
# 41354                              [/artist/asha-bhosle-1]
# Name: singer_id, Length: 36361, dtype: object

# %%
df['singer_id'].str.split('|').explode().nunique() #TOTAL SINGERS
# Out:
# 4528

# %%
#TOTAL LANGUAGES
df['language'].nunique()
# Out:
# 15

# %%
# Total Duration of Songs on Ganna
total_seconds = df['duration_in_seconds'].sum()

hours = total_seconds//3600

reamaining_seconds = total_seconds - hours*3600
minutes = reamaining_seconds//60
seconds = reamaining_seconds%60

print(hours, 'hours',minutes,'minutes',seconds,'seconds')
# Out:
# 3160 hours 21 minutes 7 seconds

# %%
# TOP 10 Songs
df.groupby('name')['duration'].count().sort_values(ascending = False).head(10)
# Out:
# name
# Padhyams                       20
# V                              14
# Ninna Nanna                    14
# O Mere Dil Ke Chain            13
# Ahe Ramahari                   12
# Yedhalo Tholivalape            12
# Naguva Nayana                  12
# Tuma Gaan Mahu Machhi          12
# Preethine Aa Dyavaru Thanda    11
# Muttina Hanigalu               11
# Name: duration, dtype: int64

# %%
# Top 5 Languages
df['language'].value_counts().sort_values(ascending = False).head()
# Out:
# language
# Telugu     4995
# Hindi      4993
# Marathi    4699
# Tamil      4677
# Punjabi    3818
# Name: count, dtype: int64

# %%
# Top 10 singers with most number of solo

df['singer_id'].value_counts().head(10)
# Out:
# singer_id
# /artist/s-p-balasubrahamanyam                        1155
# /artist/asha-bhosle-1                                1037
# /artist/p-suseela-2                                  1019
# /artist/lata-mangeshkar                               856
# /artist/s-janaki                                      728
# /artist/mohammad-rafi                                 698
# /artist/s-p-balasubrahamanyam|/artist/p-suseela-2     682
# /artist/kishore-kumar                                 663
# /artist/noor-jehan                                    489
# /artist/s-p-balasubrahamanyam|/artist/s-janaki        455
# Name: count, dtype: int64

# %%
# Average duration of songs in all languages
df.groupby('language')['duration_in_seconds'].mean().sort_values(ascending = False)
# Out:
# language
# Punjabi       448.317968
# Urdu          410.692875
# Bhojpuri      364.073218
# Haryanvi      320.004386
# Telugu        314.183584
# Hindi         310.096936
# Rajasthani    291.040665
# Marathi       282.762290
# Tamil         273.258927
# Gujarati      271.632151
# Odia          257.629787
# Bengali       255.179541
# Kannada       252.726890
# Malayalam     242.609603
# Assamese      228.325967
# Name: duration_in_seconds, dtype: float64

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LinearSegmentedColormap

# Your existing code
singer_counts = df['singer_id'].str.split(',').explode().value_counts().head(30)

plt.figure(figsize=(12, 6))

# Define a custom red colormap
cmap_red = LinearSegmentedColormap.from_list("my_cmap", ["darkred", "lightcoral"])

# Generate colors based on the custom colormap
colors = cmap_red(np.linspace(0, 1, len(singer_counts)))

# Create the bar plot with gradient colors
ax = singer_counts.plot(kind='bar', color=colors, width=0.7)

# Customize the plot
plt.xlabel("Singer ID")
plt.ylabel("Number of Songs")
plt.title("Top 30 Singers by Song Count")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()

# %%
import plotly.express as px
import pandas as pd

# Your existing code
singer_counts = df['singer_id'].str.split('|').explode().value_counts().head(30)
singer_counts_df = singer_counts.reset_index()  # Convert to DataFrame for Plotly
singer_counts_df.columns = ['singer_id', 'count']  # Rename columns

# Create the Plotly bar chart
fig = px.bar(
    singer_counts_df,
    x='singer_id',
    y='count',
    color='count',  # Use 'count' for color scale
    color_continuous_scale=['darkred','lightcoral'],  # Set the color scale
)

# Customize the layout
fig.update_layout(
    title="Top 30 Singers by Song Count",
    xaxis_title="Singer ID",
    yaxis_title="Number of Songs",
    xaxis_tickangle=-45,  # Rotate x-axis labels
    width=1200,  # Adjust width
    height=600  # Adjust height
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
import pandas as pd

# Your existing code
language_counts = df['language'].value_counts().sort_values(ascending=False).head()
language_counts_df = language_counts.reset_index()
language_counts_df.columns = ['language', 'count']

# Create the Plotly donut chart
fig = px.pie(
    language_counts_df,
    values='count',
    names='language',
    hole=0.4,  # Create the hole for the donut
    color_discrete_sequence=['rgb(199, 73, 88)', 'indianred', 'firebrick', 'maroon', 'darkred']  # Custom color sequence
)

# Customize the layout
fig.update_layout(
    title="Top 5 Languages",
    width=600,
    height=600,
    legend_title="Language",
)
fig.update_traces(textinfo='percent+label')  # Show percentage and label on slices

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
import pandas as pd
import colorsys

def adjust_lightness(rgb, factor):
    h, l, s = colorsys.rgb_to_hls(rgb[0]/255.0, rgb[1]/255.0, rgb[2]/255.0)
    l = max(min(l * factor, 1.0), 0.0)  # Clamp lightness to 0-1 range
    r, g, b = colorsys.hls_to_rgb(h, l, s)
    return f'rgb({int(r*255)},{int(g*255)},{int(b*255)})'

# Your existing code
language_counts = df['language'].value_counts().sort_values(ascending=False).head()
language_counts_df = language_counts.reset_index()
language_counts_df.columns = ['language', 'count']

# Base RGB color
base_rgb = (199, 73, 88)

# Generate color sequence
color_sequence = [
    adjust_lightness(base_rgb, 1.5),  # Lighter shade 1
    adjust_lightness(base_rgb, 1.2),  # Lighter shade 2
    adjust_lightness(base_rgb, 1.0),  # Original color
    adjust_lightness(base_rgb, 0.8),  # Darker shade 1
    adjust_lightness(base_rgb, 0.6),  # Darker shade 2
]

# Create the Plotly donut chart
fig = px.pie(
    language_counts_df,
    values='count',
    names='language',
    hole=0.4,
    color_discrete_sequence=color_sequence
)

fig.update_layout(
    title="Top 5 Languages",
    width=600,
    height=600,
    legend_title="Language",
)
fig.update_traces(textinfo='percent+label')  # Show percentage and label on slices

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
