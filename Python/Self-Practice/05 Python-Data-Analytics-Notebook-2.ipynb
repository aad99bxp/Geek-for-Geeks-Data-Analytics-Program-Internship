# %% [markdown]
# # OPERATORS

# %% [markdown]
# ## 1. ARITHMETIC OPERATORS

# %%
x=2
y=3

print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x//y)
print(x%y)
print(x**y)
# Out:
# 5
# -1
# 6
# 0.6666666666666666
# 0
# 2
# 8

# %% [markdown]
# ### NOTES:
#
# 1)Floor Division- (//) - it gives one lesser number without decimals.
#
# floor of 3.4 is 3
#
# floor of -3.4 is -4 (in negative number series, the greater number value is bigger
#
#
# 2)/ - divsion uses floating point aithmetic and thus it may not be accurate for division of large values because floating point division requires higher bits to store numbers. However the floor division uses integer point arithmetic.
#
# 3)If you have declared a variabe x and then declared another variable y =x, it will not create another memory location instead refer to x.

# %% [markdown]
# ## 2. LOGICAL OPERATORS
#
# In Python, Logical operators are used on conditional statements (either True or False). They perform Logical AND, Logical OR and Logical NOT operations.
#
# ![image.png](attachment:a920001b-b663-4e37-b988-2127745f07f0.png)

# %%
# Python program to demonstrate
# logical and operator

a = 10
b = 10
c = -10

if a > 0 and b > 0:
    print("The numbers are greater than 0")

if a > 0 and b > 0 and c > 0:
    print("The numbers are greater than 0")
else:
    print("Atleast one number is not greater than 0")
# Out:
# The numbers are greater than 0
# Atleast one number is not greater than 0

# %% [markdown]
# ### 1)Shortcircuiting
# happens in almost all langauges. so if a expression is returned false ahead of false operator, it does not operate or calculate futher, It also happens in python. Same goes for OR opeartor if the first returns true, it does not evaluate true.
#
# example: a=10
#
# b=20
#
# c-30
#
# print(a>b and b<c) - here since a>b is false, it will stop here and return false.
#
#
#
# ### 2) Note:
#
# s1="" #empty string
#
# s2= s1 or "defaultstr" #assign s1 to s2 if not empty or else assign defaultstr
#
# print(s2)
#
# output- defaultstr
#
#
#
# ### 3) Case
#
# x=10
#
# print( x or 20)
#
# y=0
#
# print (y or 30)
#
# z=40
#
# print(z and 50)
#
#
# Output: 10, 30, 50. (SHORTCIRCUITING)

# %%
# Python program to demonstrate
# logical or operator

a = 10
b = -10
c = 0

if a > 0 or b > 0:
    print("Either of the number is greater than 0")
else:
    print("No number is greater than 0")

if b > 0 or c > 0:
    print("Either of the number is greater than 0")
else:
    print("No number is greater than 0")
# Out:
# Either of the number is greater than 0
# No number is greater than 0

# %%
# Python program to demonstrate
# logical not operator

a = 10

if not a:
    print("Boolean value of a is True")

if not (a%3 == 0 or a%5 == 0):
    print("10 is not divisible by either 3 or 5")
else:
    print("10 is divisible by either 3 or 5")
# Out:
# 10 is divisible by either 3 or 5

# %% [markdown]
# ## MEMBERSHIP AND IDENTITY COMPARISON OPERATORS

# %% [markdown]
# ### MEMBERSHIP OPERATORS (IN/ NOT IN )
#
# Python offers two membership operators to check or validate the membership of a value. It tests for membership in a sequence, such as strings, lists, or tuples.
#
# #### in operator:
# The ‘in’ operator is used to check if a character/ substring/ element exists in a sequence or not. Evaluate to True if it finds the specified element in a sequence otherwise.
#
# 'G' in 'GeeksforGeeks'   # Checking 'G' in String
# True
#
# #### not in opeartor
# 'not in' operator- Evaluates to true if it does not finds a variable in the specified sequence and false otherwise.

# %%
# Python program to illustrate
# Finding common member in list
# using 'in' operator
a = [1, 2, 3, 4, 5]
b = [6, 7, 8, 9]
for item in a:
    if item in b:
        print("overlapping")
    else:
        print("not overlapping")
# Out:
# not overlapping
# not overlapping
# not overlapping
# not overlapping
# not overlapping

# %%
# Python program to illustrate
# Finding common member in list
# without  using 'in' operator

#  Define a function() that takes two lists


def overlapping(a, b):

    c = 0
    d = 0
    for i in a:
        c += 1
    for i in b:
        d += 1
    for i in range(0, c):
        for j in range(0, d):
            if(a[i] == b[j]):
                return 1
    return 0


a = [1, 2, 3, 4, 5]
b = [6, 7, 8, 9]
if(overlapping(a, b)):
    print("overlapping")
else:
    print("not overlapping")
# Out:
# not overlapping

# %%
# Python program to illustrate
# not 'in' operator
x = 24
y = 20
list = [10, 20, 30, 40, 50]

if (x not in list):
    print("x is NOT present in given list")
else:
    print("x is  present in given list")

if (y in list):
    print("y is present in given list")
else:
    print("y is NOT present in given list")
# Out:
# x is NOT present in given list
# y is present in given list

# %% [markdown]
# ### IDENTITY COMPARISON OPERATORS (IS/IS NOT
#
# Identity operators are used to compare the objects if both the objects are actually of the same data type and share the same memory location.
# There are different identity operators such as
#
# #### 'is' operator -
# Evaluates to True if the variables on either side of the operator point to the same object and false otherwise.
#
# #### 'is not' operator -
# Evaluates to false if the variables on either side of the operator point to a different object and true otherwise.

# %%
# Python program to illustrate the
# use of 'is not' identity operator
x = 5
if (type(x) is not int):
    print("true")
else:
    print("false")

# Prints True
x = 5.6
if (type(x) is not int):
    print("true")
else:
    print("false")
# Out:
# false
# true

# %% [markdown]
# #### BITWISE OPERATORS
#
# ![image.png](attachment:a6ac6f2a-4e2d-4aba-b6a0-e4cd31304664.png)
#
# Bitwise AND operator: Returns 1 if both the bits are 1 else 0.
# Example:
#
# a = 10 = 1010 (Binary)
# b = 4 =  0100 (Binary)
#
# a & b = 1010
#          &
#         0100
#       = 0000
#       = 0 (Decimal)

# %%
# Python program to show
# bitwise operators

a = 10
b = 4

# Print bitwise AND operation
print("a & b =", a & b)

# Print bitwise OR operation
print("a | b =", a | b)

# Print bitwise NOT operation
print("~a =", ~a)

# print bitwise XOR operation
print("a ^ b =", a ^ b)
# Out:
# a & b = 0
# a | b = 14
# ~a = -11
# a ^ b = 14

# %%
# Python program to show
# shift operators

a = 10
b = -10

# print bitwise right shift operator
print("a >> 1 =", a >> 1)
print("b >> 1 =", b >> 1)

a = 5
b = -10

# print bitwise left shift operator
print("a << 1 =", a << 1)
print("b << 1 =", b << 1)
# Out:
# a >> 1 = 5
# b >> 1 = -5
# a << 1 = 10
# b << 1 = -20
