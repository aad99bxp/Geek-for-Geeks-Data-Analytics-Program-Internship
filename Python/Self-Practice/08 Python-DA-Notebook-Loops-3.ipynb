# %% [markdown]
# # LOOPS

# %%
# If no incremeent/dectement is set inside the while loop, it will run Infinite times
# Intentionally, infinte loops are written as :
while True:
    print("Abhay")

# %%
# Take a number as input and write your name thaat number of times
n= int(input("Input the number"))
i =0
while i<n:
    print("Abhay")
    i+=1
# Out:
# Input the number 2
# Abhay
# Abhay

# %%
# checks if list still
# contains any element
a = [1, 2, 3, 4]
  
while a:
    print(a.pop())
# Out:
# 4
# 3
# 2
# 1

# %% [markdown]
# ### RANGE
#
# The Python range() function returns a sequence of numbers, in a given range. The most common use of it is to iterate sequences on a sequence of numbers using Python loops.
#
# Syntax:
#
# Syntax: range(start, stop, step)
#
# Parameter:
#
# #### start: [ optional ] start value of the sequence
#
# #### stop: next value after the end value of the sequence
#
# #### step: [ optional ] integer value, denoting the difference between any two numbers in the sequence.
#
# Return: Returns a range type object.
#
# ![image.png](attachment:b6dcf68d-3bc0-42f0-b896-70105e478204.png)
#
# ![image.png](attachment:ed9e8418-3163-402f-9602-8d8c858ecaf0.png)
#
# ![image.png](attachment:ab729ff2-bff6-4649-bb26-b829828797c6.png)

# %%
for i in range(0, 10, 2):
    print(i, end=" ")
print()
# Out:
# 0 2 4 6 8

# %%
r =range(3)
l= list(r)
print (l)
# Out:
# [0, 1, 2]

# %% [markdown]
# ### FOR LOOP

# %%
for i in l:
    print(i)
# Out:
# 0
# 1
# 2

# %%
x= "abhay"
for i in x:
    print(i)
# Out:
# a
# b
# h
# a
# y

# %%
for i in range(3):
   print(i)
# Out:
# 0
# 1
# 2

# %%
l = [10,20,30,40]
for i in range(len(l)):
    print(l[i])
# Out:
# 10
# 20
# 30
# 40

# %%
# Iterating over dictionary
print("Dictionary Iteration")
d = dict()
d['xyz'] = 123
d['abc'] = 345
for i in d:
    print("% s % d" % (i, d[i]))
# Out:
# Dictionary Iteration
# xyz  123
# abc  345

# %%
# Take a input of number and return the table upto 10 for that number
n = int(input("Enter the number"))
for i in range(1,11):
    print(n,'x',i,'=',n*i)
# Out:
# Enter the number 3
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %% [markdown]
# ### BREAK AND CONTINUE
# Break statement in Python is used to bring the control out of the loop when some external condition is triggered.
#
# Python Continue statement is a loop control statement that forces to execute the next iteration of the loop while skipping the rest of the code inside the loop for the current iteration only

# %%
n = 0
for i in range(10):
    n += 1
    if n == 8:
        break
    print("The n has value:", n)
print("Out of loop")
# Out:
# The n has value: 1
# The n has value: 2
# The n has value: 3
# The n has value: 4
# The n has value: 5
# The n has value: 6
# The n has value: 7
# Out of loop

# %%
# loop from 1 to 10
for i in range(1, 11):
 
    # If i is equals to 6,
    # continue to next iteration
    # without printing
    if i == 6:
        continue
    else:
        # otherwise print the value
        # of i
        print(i, end=" ")
# Out:
# 1 2 3 4 5 7 8 9 10

# %%
#Print numbers from the list which are multiple of 5 and skip those which arent
l =[10,3,7,2,15,20]
for i in l:
    if i%5==0:
        continue
    print(i)
# Out:
# 3
# 7
# 2
